# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the image
data = np.array(plt.imread('./images/sign.jpg'))

# %%
a = plt.imread('./images/sign.jpg')
a.shape
# Out:
# (174, 290, 3)

# %%
# Display the image
plt.imshow(a)

# %%
# Change the some parts of the image
a = np.array(plt.imread('./images/sign.jpg'))
a[60:120, 80:110] = (100, 200, 100)
plt.imshow(a)

# %%
data[:, :, 1] = 0 # Green
data[:, :, 2] = 0 # Blue
plt.imshow(data)
plt.show()

# %%
b = np.array(plt.imread('./images/sign.jpg'))
b.shape
# Out:
# (174, 290, 3)

# %%
gray_img = b[:, :, 0]//3 + b[:, :, 1]//3 + b[:, :, 2]//3
plt.imshow(gray_img, cmap='gray')
